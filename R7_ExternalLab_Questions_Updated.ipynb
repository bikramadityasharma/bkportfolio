# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
from __future__ import absolute_import, division, print_function
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train_num), (x_test, y_test_num) = fashion_mnist.load_data()

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
print('--- THE DATA ---')

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
y_train =  tf.keras.utils.to_categorical(y_train_num, 10)
y_test = tf.keras.utils.to_categorical(y_test_num, 10)
# Out:
# --- THE DATA ---
# 60000 train samples
# 10000 test samples

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

#Reshape data from 2D to 1D -> 28x28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,1)))


#Add 1st hidden layer
model.add(tf.keras.layers.Dense(200, activation='relu'))

    
# Dropout
model.add(tf.keras.layers.Dropout(0.25))

#Add 2nd hidden layer
model.add(tf.keras.layers.Dense(100, activation='relu'))

#Add OUTPUT layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

#Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Store Training Results
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1, mode='auto')
callback_list = [early_stopping]# [stats, early_stopping]

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_6 (Reshape)          (None, 784)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 200)               157000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 100)               20100
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 178,110
# Trainable params: 178,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE = 32
EPOCHS = 5

# %%
model.fit(x_train, y_train, nb_epoch=EPOCHS, batch_size=BATCH_SIZE, 
           validation_data=(x_test, y_test), callbacks=callback_list, verbose=True)
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.5281 - accuracy: 0.8088 - val_loss: 0.4507 - val_accuracy: 0.8341
# Epoch 2/5
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.4073 - accuracy: 0.8487 - val_loss: 0.3989 - val_accuracy: 0.8544
# Epoch 3/5
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.3749 - accuracy: 0.8618 - val_loss: 0.3760 - val_accuracy: 0.8656
# Epoch 4/5
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.3501 - accuracy: 0.8708 - val_loss: 0.3724 - val_accuracy: 0.8668
# Epoch 5/5
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.3366 - accuracy: 0.8752 - val_loss: 0.3594 - val_accuracy: 0.8730

# %%
loss_and_metrics = model.evaluate(x_test, y_test)
print("Loss & Metrics: ",loss_and_metrics)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Loss & Metrics:  [0.3594494274377823, 0.873]
